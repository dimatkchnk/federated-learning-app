# %%
import matplotlib.pyplot as plt
import pydicom
from pydicom.pixel_data_handlers.util import apply_modality_lut, apply_voi_lut, apply_windowing

# %%
image_path = "/home/dimatkchnk/praca_dyplomowa/dicom/1.dicom"
image_path2 = "/home/dimatkchnk/praca_dyplomowa/dicom/2.dicom"
image_path3 = "/home/dimatkchnk/praca_dyplomowa/dicom/3.dcm"

# %%
ds = pydicom.dcmread(image_path)

# %%
plt.imshow(ds.pixel_array)

# %%
def show_dicom_file(image_path):
    ds = pydicom.dcmread(image_path)
    plt.imshow(ds.pixel_array)

# %%
show_dicom_file("/home/dimatkchnk/praca_dyplomowa/dicom/2.dicom")

# %%
show_dicom_file("/home/dimatkchnk/praca_dyplomowa/dicom/3.dcm")

# %%
print(ds)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 158
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Digital Mammography X-Ray Image Storage - For Presentation
# (0002, 0003) Media Storage SOP Instance UID      UI: 2aca993b3b6e2a32dddd170b00fd5e7d
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.3.4
# (0002, 0013) Implementation Version Name         SH: 'RadiAnt-2020.1.1'
# -------------------------------------------------
# (0008, 0018) SOP Instance UID                    UI: 2aca993b3b6e2a32dddd170b00fd5e7d
# (0008, 0060) Modality                            CS: 'MG'
# (0008, 0068) Presentation Intent Type            CS: 'FOR PRESENTATION'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 1090) Manufacturer's Model Name           LO: 'Mammomat Inspiration'
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: '037Y'
# (0018, 0015) Body Part Examined                  CS: 'BREAST'
# (0018, 1164) Imager Pixel Spacing                DS: [0.085, 0.085]
# (0018, 5101) View Position                       CS: 'CC'
# (0020, 000d) Study Instance UID                  UI: 0034765af074f93ed33d5e8399355caf
# (0020, 000e) Series Instance UID                 UI: 91de7075b7eb54cc4fc959ef67b9df56
# (0020, 0062) Image Laterality                    CS: 'R'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 3518
# (0028, 0011) Columns                             US: 2800
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0120) Pixel Padding Value                 US: 0
# (0028, 1050) Window Center                       DS: '1681.0'
# (0028, 1051) Window Width                        DS: '1500.0'
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'US'
# (0028, 1055) Window Center & Width Explanation   LO: 'linear LUT'
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0028, 3010)  VOI LUT Sequence  5 item(s) ----
#    (0028, 3002) LUT Descriptor                      US: [4096, 0, 12]
#    (0028, 3003) LUT Explanation                     LO: 'High Contrast'
#    (0028, 3006) LUT Data                            US: Array of 4096 elements
#    ---------
#    (0028, 3002) LUT Descriptor                      US: [4096, 0, 12]
#    (0028, 3003) LUT Explanation                     LO: 'Medium Contrast (Dark)'
#    (0028, 3006) LUT Data                            US: Array of 4096 elements
#    ---------
#    (0028, 3002) LUT Descriptor                      US: [4096, 0, 12]
#    (0028, 3003) LUT Explanation                     LO: 'Medium Contrast (Bright)'
#    (0028, 3006) LUT Data                            US: Array of 4096 elements
#    ---------
#    (0028, 3002) LUT Descriptor                      US: [4096, 0, 12]
#    (0028, 3003) LUT Explanation                     LO: 'Low Contrast'
#    (0028, 3006) LUT Data                            US: Array of 4096 elements
#    ---------
#    (0028, 3002) LUT Descriptor                      US: [4096, 0, 12]
#    (0028, 3003) LUT Explanation                     LO: 'US_LUT'
#    (0028, 3006) LUT Data                            US: Array of 4096 elements
#    ---------
# (2050, 0020) Presentation LUT Shape              CS: 'IDENTITY'
# (7fe0, 0010) Pixel Data                          OW: Array of 19700800 elements
# /home/dimatkchnk/.local/lib/python3.11/site-packages/pydicom/valuerep.py:290: UserWarning: Invalid value for VR UI: '2aca993b3b6e2a32dddd170b00fd5e7d'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warnings.warn(msg)
# /home/dimatkchnk/.local/lib/python3.11/site-packages/pydicom/valuerep.py:290: UserWarning: Invalid value for VR UI: '0034765af074f93ed33d5e8399355caf'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warnings.warn(msg)
# /home/dimatkchnk/.local/lib/python3.11/site-packages/pydicom/valuerep.py:290: UserWarning: Invalid value for VR UI: '91de7075b7eb54cc4fc959ef67b9df56'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warnings.warn(msg)

# %%
ds.file_meta
# Out:
# (0002, 0000) File Meta Information Group Length  UL: 158
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Digital Mammography X-Ray Image Storage - For Presentation
# (0002, 0003) Media Storage SOP Instance UID      UI: 2aca993b3b6e2a32dddd170b00fd5e7d
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.3.4
# (0002, 0013) Implementation Version Name         SH: 'RadiAnt-2020.1.1'

# %%
ds[0x0010, 0x0040]
# Out:
# (0010, 0040) Patient's Sex                       CS: 'F'

# %%
ds[0x0010, 0x0040].value
# Out:
# 'F'

# %%
def load_image_pydicom(img_path, voi_lut=False, modality_lut=False, windowing=False):
    dataset = pydicom.dcmread(img_path)
    img = dataset.pixel_array
    if voi_lut:
        img = apply_voi_lut(img, dataset)
    if modality_lut:
        img = apply_modality_lut(img, dataset)
    if windowing:
        img = apply_windowing(img, dataset)
    if dataset.PhotometricInterpretation == "MONOCHROME1":
        img = np.amax(img) - img
    return img

# %%
ds2 = pydicom.dcmread(image_path2)

print(ds2)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 158
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Digital Mammography X-Ray Image Storage - For Presentation
# (0002, 0003) Media Storage SOP Instance UID      UI: 6c4c8ea04f9fd60b26e6480d988c1e58
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.3.4
# (0002, 0013) Implementation Version Name         SH: 'RadiAnt-2020.1.1'
# -------------------------------------------------
# (0008, 0018) SOP Instance UID                    UI: 6c4c8ea04f9fd60b26e6480d988c1e58
# (0008, 0060) Modality                            CS: 'MG'
# (0008, 0068) Presentation Intent Type            CS: 'FOR PRESENTATION'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 1090) Manufacturer's Model Name           LO: 'Mammomat Inspiration'
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: '064Y'
# (0018, 0015) Body Part Examined                  CS: 'BREAST'
# (0018, 1164) Imager Pixel Spacing                DS: [0.085, 0.085]
# (0018, 5101) View Position                       CS: 'CC'
# (0020, 000d) Study Instance UID                  UI: 00a7a306c763ab5f0cb6a846825b7d04
# (0020, 000e) Series Instance UID                 UI: 553dcee6eb7a73bcccfe4c50cd0b8c15
# (0020, 0062) Image Laterality                    CS: 'L'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 3518
# (0028, 0011) Columns                             US: 2800
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0120) Pixel Padding Value                 US: 0
# (0028, 1050) Window Center                       DS: '1705.0'
# (0028, 1051) Window Width                        DS: '1500.0'
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'US'
# (0028, 1055) Window Center & Width Explanation   LO: 'linear LUT'
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0028, 3010)  VOI LUT Sequence  5 item(s) ----
#    (0028, 3002) LUT Descriptor                      US: [4096, 0, 12]
#    (0028, 3003) LUT Explanation                     LO: 'High Contrast'
#    (0028, 3006) LUT Data                            US: Array of 4096 elements
#    ---------
#    (0028, 3002) LUT Descriptor                      US: [4096, 0, 12]
#    (0028, 3003) LUT Explanation                     LO: 'Medium Contrast (Dark)'
#    (0028, 3006) LUT Data                            US: Array of 4096 elements
#    ---------
#    (0028, 3002) LUT Descriptor                      US: [4096, 0, 12]
#    (0028, 3003) LUT Explanation                     LO: 'Medium Contrast (Bright)'
#    (0028, 3006) LUT Data                            US: Array of 4096 elements
#    ---------
#    (0028, 3002) LUT Descriptor                      US: [4096, 0, 12]
#    (0028, 3003) LUT Explanation                     LO: 'Low Contrast'
#    (0028, 3006) LUT Data                            US: Array of 4096 elements
#    ---------
#    (0028, 3002) LUT Descriptor                      US: [4096, 0, 12]
#    (0028, 3003) LUT Explanation                     LO: 'US_LUT'
#    (0028, 3006) LUT Data                            US: Array of 4096 elements
#    ---------
# (2050, 0020) Presentation LUT Shape              CS: 'IDENTITY'
# (7fe0, 0010) Pixel Data                          OW: Array of 19700800 elements
# /home/dimatkchnk/.local/lib/python3.11/site-packages/pydicom/valuerep.py:290: UserWarning: Invalid value for VR UI: '6c4c8ea04f9fd60b26e6480d988c1e58'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warnings.warn(msg)
# /home/dimatkchnk/.local/lib/python3.11/site-packages/pydicom/valuerep.py:290: UserWarning: Invalid value for VR UI: '00a7a306c763ab5f0cb6a846825b7d04'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warnings.warn(msg)
# /home/dimatkchnk/.local/lib/python3.11/site-packages/pydicom/valuerep.py:290: UserWarning: Invalid value for VR UI: '553dcee6eb7a73bcccfe4c50cd0b8c15'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warnings.warn(msg)

# %%
img = load_image_pydicom(image_path2)
img_voi = load_image_pydicom(image_path2, voi_lut=True)

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.title("RAW")
plt.imshow(img, cmap='gray')

plt.subplot(122)
plt.title("VOI LUT")
plt.imshow(img_voi, cmap='gray')

# %%
img = load_image_pydicom(image_path2)
img_voi = load_image_pydicom(image_path2, windowing=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 img = load_image_pydicom(image_path2)
#       2 img_voi = load_image_pydicom(image_path2, windowing=True)
#
# NameError: name 'load_image_pydicom' is not defined

# %%
img = load_image_pydicom(image_path2, voi_lut=True)
img_voi = load_image_pydicom(image_path2, voi_lut=False, modality_lut=True, windowing=True)

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.title("VOI LUT")
plt.imshow(img, cmap='gray')

plt.subplot(122)
plt.title("MODALITY LUT, WINDOWING")
plt.imshow(img_voi, cmap='gray')

# %%
img = load_image_pydicom(image_path2, voi_lut=True)
img_voi = load_image_pydicom(image_path2, windowing=True)

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.title("VOI LUT")
plt.imshow(img, cmap='gray')

plt.subplot(122)
plt.title("WINDOWING")
plt.imshow(img_voi, cmap='gray')

# %%
img = load_image_pydicom(image_path2, voi_lut=True)
img_voi = load_image_pydicom(image_path2, voi_lut=True, modality_lut=True)

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.title("VOI LUT")
plt.imshow(img, cmap='gray')

plt.subplot(122)
plt.title("VOI LUT, MODALITY LUT")
plt.imshow(img_voi, cmap='gray')

# %%
img = load_image_pydicom(image_path)
img_voi = load_image_pydicom(image_path, voi_lut=True)

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.title("RAW")
plt.imshow(img, cmap='gray')

plt.subplot(122)
plt.title("VOI LUT")
plt.imshow(img_voi, cmap='gray')

# %%
ds3 = pydicom.dcmread(image_path3)

# %%
print(ds3)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Digital X-Ray Image Storage - For Presentation
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.10009.1.2.3.10008.1.1591370361
# (0002, 0010) Transfer Syntax UID                 UI: JPEG 2000 Image Compression (Lossless Only)
# (0002, 0012) Implementation Class UID            UI: 1.2.840.113654.2.3.1995.2.12.0
# (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
# -------------------------------------------------
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.10009.1.2.3.10008.1.1591370361
# (0008, 0023) Content Date                        DA: '20221118'
# (0008, 0033) Content Time                        TM: '183902.513856'
# (0010, 0020) Patient ID                          LO: '10008'
# (0020, 000d) Study Instance UID                  UI: 1.2.840.10009.1.2.3.10008
# (0020, 000e) Series Instance UID                 UI: 1.2.840.10009.1.2.3.10008.1
# (0020, 0013) Instance Number                     IS: '1591370361'
# (0020, 0062) Image Laterality                    CS: 'L'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 2776
# (0028, 0011) Columns                             US: 2082
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0120) Pixel Padding Value                 US: 0
# (0028, 1040) Pixel Intensity Relationship        CS: 'LOG'
# (0028, 1041) Pixel Intensity Relationship Sign   SS: 1
# (0028, 1050) Window Center                       DS: '2048.0'
# (0028, 1051) Window Width                        DS: '4096.0'
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'US'
# (0028, 1350) Partial View                        CS: 'NO'
# (0028, 2110) Lossy Image Compression             CS: '00'
# (7fe0, 0010) Pixel Data                          OW: Array of 2873866 elements

# %%
img = load_image_pydicom(image_path3)
img_voi = load_image_pydicom(image_path3, voi_lut=True)

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.title("RAW")
plt.imshow(img, cmap='gray')

plt.subplot(122)
plt.title("VOI LUT")
plt.imshow(img_voi, cmap='gray')

# %%
img = load_image_pydicom(image_path3)
img_voi = load_image_pydicom(image_path3, modality_lut=True)

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.title("RAW")
plt.imshow(img, cmap='gray')

plt.subplot(122)
plt.title("MODALITY")
plt.imshow(img_voi, cmap='gray')
